# %% [markdown]
# models

# %%
''''
models.py (dataclasses, Order, exceptions)

----------------------------------------------------------------------------
Mutable Order Management
Implement an Order class with mutable attributes: symbol, quantity, price, and status.
Demonstrate in a unit test that you can update Order.status but not MarketDataPoint.price.

class OrderError(Exception)
class MarketDataPoint
class Order
class TestOrderAndMarketData(unittest.TestCase)
class MarketDataContainer:

----------------------------------------------------------------------------
Exception Handling

Define custom exceptions:

class OrderError(Exception): pass
class ExecutionError(Exception): pass
Raise OrderError for invalid orders (e.g., zero or negative quantity).
In the execution engine, simulate occasional failures and raise ExecutionError; catch and log these errors to continue processing.
'''

import unittest
from dataclasses import FrozenInstanceError
from dataclasses import dataclass
import datetime as datetime
# Exception Handling
class OrderError(Exception): 
    def __init__(self,error):
        super().__init__("This order is not valid")
class ExecutionError(Exception): pass


# define frozen data class
#immutable
@dataclass(frozen = True)
class MarketDataPoint:
    timestamp : datetime.datetime
    symbol : str
    price: float


#mutable
class Order:
    def __init__(self,symbol:str,quantity:int ,price:float,side:str,status:str):
        self.symbol = symbol
        self.quantity = quantity # validate via setter
        self.price = price # validate via setter
        self.side = side
        self.status = status
        timestamp: datetime

    @property
    def price(self):
        return self.price
    
    @price.setter
    def price(self,value):
        if value < 0:
            raise OrderError("Price cannot be negative")
        self.price = value

    @property
    def quantity(self):
        return self.quantity
    @quantity.setter
    def quantity(self, v: int):
        if v <= 0:
            raise OrderError("quantity must be > 0")
        self._quantity = int(v)

    @property
    def value(self):
        return self.price* self.quantity
    
    def __str__(self):
        return f"{self.quantity} shares of {self.symbol} at ${self.price:.2f}"
    
    def __repr__(self):
        return f"Order('{self.symbol}',{self.quantity},{self.price})"



# unit test
'''
(maybe deleted later)
'''
class TestOrderAndMarketData(unittest.TestCase):
    def test_mutable_order(self):
        order = Order("AAPL", 10, 150.0,"bid","NEW")
        self.assertEqual(order.status, "NEW")
        order.status = "FILLED"
        self.assertEqual(order.status, "FILLED")

    def test_immutable_marketdatapoint(self):
        point = MarketDataPoint(datetime.datetime.now(), "AAPL", 150.0)
        with self.assertRaises(FrozenInstanceError):
            point.price = 200.0

class MarketDataContainer:
    def __init__(self):
        self.buffer = []
        self.all_positions = {}
        self.trade_signal = []

    def buffer_data(self, data_point):
        self.buffer.append(data_point)

    def add_trade_signal(self, action, symbol, quantity, price):
        self.trade_signal.append((action, symbol, quantity, price))

    def calculate_average_price(self, position):
        if position["total_shares"] > 0:
            position["average_price"] = position["total_cost"] / position["total_shares"]
        else:
            position["average_price"] = 0.0

    def update_position(self, order):
        symbol = order['symbol']
        side = str(order['side']).upper()
        quantity = int(order['quantity'])
        price = float(order['price'])

        if symbol not in self.all_positions:
            self.all_positions[symbol] = {
                "total_shares": 0,
                "total_cost": 0.0,
                "average_price": 0.0
            }
        position = self.all_positions[symbol]

        if side == "BUY":
            position["total_shares"] += quantity
            position["total_cost"] += price * quantity
            self.calculate_average_price(position)

        elif side == "SELL":
            sell_quantity = min(quantity, position["total_shares"])
            if quantity > position["total_shares"]:
                print(f"CANNOT OVERSELL! Currently have shares: {position['total_shares']}. But wanted to sell {quantity}. PROCEED with selling {sell_quantity} shares.")

            position["total_shares"] -= sell_quantity
            position["total_cost"] -= position["average_price"] * sell_quantity
            if position["total_shares"] <= 0:
                position["total_cost"] = 0.0
                position["average_price"] = 0.0
            self.calculate_average_price(position)

    def fetch_current_position(self, symbol):
        return self.all_positions.get(symbol, {
            "total_shares": 0,
            "total_cost": 0.0,
            "average_price": 0.0
        })

# %% [markdown]
# data loader

# %%
"""
Data Ingestion & Immutable Types

Read market_data.csv (columns: timestamp, symbol, price) using the built-in csv module.

Define a frozen dataclass MarketDataPoint with attributes timestamp (datetime), symbol (str), and price (float).

Parse each row into a MarketDataPoint and collect them in a list.
"""



'''
# read data
def loadfile(csv):
    #download
    df = pd.read_csv("market_data.csv")   

    # parse row
    marketList = []       
    for i in range(len(df)):
        marketList.append(MarketDataPoint(df.iloc[i][0],df.iloc[i][1],df.iloc[i][2]))

    return marketList
'''

class MarketDataReader:
    def __init__(self, csvfile):
        self.csvfile = csvfile
        self.data_list = []

    def read_data(self):
        try:
            with open(self.csvfile, newline='') as csvfile:
                reader = csv.DictReader(csvfile)

                for row in reader:
                    try:
                        market_data_point = MarketDataPoint(
                            timestamp=datetime.datetime.fromisoformat(row["timestamp"]),
                            symbol=row["symbol"],
                            price=float(row["price"])
                        )
                        self.data_list.append(market_data_point)

                    except Exception as error_in_row:
                        print(f"There is error in row {row}: {error_in_row}")

        except Exception as error_in_csv:
            print(f"There is error reading CSV file: {error_in_csv}")
    
    def fetch_data(self):
        return self.data_list

# %% [markdown]
# model

# %%
''''
models.py (dataclasses, Order, exceptions)

----------------------------------------------------------------------------
Mutable Order Management
Implement an Order class with mutable attributes: symbol, quantity, price, and status.
Demonstrate in a unit test that you can update Order.status but not MarketDataPoint.price.

class OrderError(Exception)
class MarketDataPoint
class Order
class TestOrderAndMarketData(unittest.TestCase)
class MarketDataContainer:

----------------------------------------------------------------------------
Exception Handling

Define custom exceptions:

class OrderError(Exception): pass
class ExecutionError(Exception): pass
Raise OrderError for invalid orders (e.g., zero or negative quantity).
In the execution engine, simulate occasional failures and raise ExecutionError; catch and log these errors to continue processing.
'''

import unittest
from dataclasses import FrozenInstanceError
from dataclasses import dataclass
import datetime as datetime
# Exception Handling
class OrderError(Exception): 
    def __init__(self,error):
        super().__init__("This order is not valid")
class ExecutionError(Exception): pass


# define frozen data class
#immutable
@dataclass(frozen = True)
class MarketDataPoint:
    timestamp : datetime.datetime
    symbol : str
    price: float


#mutable
class Order:
    def __init__(self,symbol:str,quantity:int ,price:float,side:str,status:str):
        self.symbol = symbol
        self.quantity = quantity # validate via setter
        self.price = price # validate via setter
        self.side = side
        self.status = status

    @property
    def price(self):
        return self.price
    
    @price.setter
    def price(self,value):
        if value < 0:
            raise OrderError("Price cannot be negative")
        self.price = value

    @property
    def quantity(self):
        return self.quantity
    @quantity.setter
    def quantity(self, v: int):
        if v <= 0:
            raise OrderError("quantity must be > 0")
        self._quantity = int(v)

    @property
    def value(self):
        return self.price* self.quantity
    
    def __str__(self):
        return f"{self.quantity} shares of {self.symbol} at ${self.price:.2f}"
    
    def __repr__(self):
        return f"Order('{self.symbol}',{self.quantity},{self.price})"



# unit test
'''
(maybe deleted later)
'''
class TestOrderAndMarketData(unittest.TestCase):
    def test_mutable_order(self):
        order = Order("AAPL", 10, 150.0,"bid","NEW")
        self.assertEqual(order.status, "NEW")
        order.status = "FILLED"
        self.assertEqual(order.status, "FILLED")

    def test_immutable_marketdatapoint(self):
        point = MarketDataPoint(datetime.datetime.now(), "AAPL", 150.0)
        with self.assertRaises(FrozenInstanceError):
            point.price = 200.0


class MarketDataContainer:
    def __init__(self):
        self.buffer = []
        self.all_positions = {}
        self.trade_signal = []

    def buffer_data(self, data_point):
        self.buffer.append(data_point)

    def add_trade_signal(self, action, symbol, quantity, price):
        self.trade_signal.append((action, symbol, quantity, price))

    def calculate_average_price(self, position):
        if position["total_shares"] > 0:
            position["average_price"] = position["total_cost"] / position["total_shares"]
        else:
            position["average_price"] = 0.0

    def last(self):
        return self.buffer[-1] if self.buffer else None

    def recent(self, n):
        return self.buffer[-n:] if n > 0 else []

    def __len__(self):
        return len(self.buffer)

    def __iter__(self):
        return iter(self.buffer)
    
    def update_position(self, order):
        symbol = order['symbol']
        side = str(order['side']).upper()
        quantity = int(order['quantity'])
        price = float(order['price'])

        if symbol not in self.all_positions:
            self.all_positions[symbol] = {
                "total_shares": 0,
                "total_cost": 0.0,
                "average_price": 0.0
            }
        position = self.all_positions[symbol]

        if side == "BUY":
            position["total_shares"] += quantity
            position["total_cost"] += price * quantity
            self.calculate_average_price(position)

        elif side == "SELL":
            sell_quantity = min(quantity, position["total_shares"])
            if quantity > position["total_shares"]:
                print(f"CANNOT OVERSELL! Currently have shares: {position['total_shares']}. But wanted to sell {quantity}. PROCEED with selling {sell_quantity} shares.")

            position["total_shares"] -= sell_quantity
            position["total_cost"] -= position["average_price"] * sell_quantity
            if position["total_shares"] <= 0:
                position["total_cost"] = 0.0
                position["average_price"] = 0.0
            self.calculate_average_price(position)

    def fetch_current_position(self, symbol):
        return self.all_positions.get(symbol, {
            "total_shares": 0,
            "total_cost": 0.0,
            "average_price": 0.0
        })
    
class Portfolio:
    """Simple long-only position tracker per symbol."""
    def __init__(self) -> None:
        self.cash: float = 0.0
        self.positions: Dict[str, Dict[str, float]] = {}

    def _ensure(self, symbol: str):
        if symbol not in self.positions:
            self.positions[symbol] = {
                "total_shares": 0.0,
                "total_cost": 0.0,
                "average_price": 0.0,
                "realized_pnl": 0.0,
            }
        return self.positions[symbol]

    def apply_fill(self, order: Order) -> None:
        px = order.price
        qty = float(order.quantity)
        pos = self._ensure(order.symbol)
        if order.side == "BUY":
            pos["total_shares"] += qty
            pos["total_cost"] += px * qty
            pos["average_price"] = 0.0 if pos["total_shares"] == 0 else pos["total_cost"] / pos["total_shares"]
        elif order.side == "SELL":
            if qty > pos["total_shares"]:
                # allow partial sell of what's available
                qty = pos["total_shares"]
            # realized PnL on sold shares
            pos["realized_pnl"] += (px - pos["average_price"]) * qty
            pos["total_shares"] -= qty
            pos["total_cost"] = pos["average_price"] * pos["total_shares"]
            pos["average_price"] = 0.0 if pos["total_shares"] == 0 else pos["total_cost"] / pos["total_shares"]
        else:
            raise OrderError(f"Unsupported side {order.side}")

    def snapshot(self) -> Dict[str, Dict[str, float]]:
        return {k: v.copy() for k, v in self.positions.items()}

# %% [markdown]
# strategy

# %%
from __future__ import annotations
from abc import ABC, abstractmethod
from collections import deque
from typing import Dict, List, Tuple, Optional

# signal tuple: (side, symbol, qty)
Signal = Tuple[str, str, int]

class Strategy(ABC):
    @abstractmethod
    def generate_signals(self, tick, positions: Optional[Dict[str, Dict[str, float]]] = None) -> List[Signal]:
        ...

class MovingAverageCrossover(Strategy):
    def __init__(self, symbol: str, short_window: int = 5, long_window: int = 20, trade_qty: int = 1):
        if not (1 <= short_window < long_window):
            raise ValueError("Require 1 <= short_window < long_window")
        self.symbol = symbol
        self._short_w = short_window
        self._long_w = long_window
        self._prices = deque(maxlen=long_window)
        self._prev_diff = None
        self._qty = trade_qty

    def generate_signals(self, tick, positions=None):
        if tick.symbol != self.symbol:
            return []
        self._prices.append(tick.price)
        if len(self._prices) < self._long_w:
            return []
        short_ma = sum(list(self._prices)[-self._short_w:]) / self._short_w
        long_ma = sum(self._prices) / self._long_w
        diff = short_ma - long_ma

        signals: List[Signal] = []
        if self._prev_diff is not None:
            # Cross up
            if self._prev_diff <= 0 and diff > 0:
                signals.append(("BUY", tick.symbol, self._qty))
            # Cross down
            elif self._prev_diff >= 0 and diff < 0:
                # sell only up to current shares
                current = 0
                if positions and tick.symbol in positions:
                    current = int(positions[tick.symbol].get("total_shares", 0))
                qty = min(current, self._qty) if current > 0 else 0
                if qty > 0:
                    signals.append(("SELL", tick.symbol, qty))
        self._prev_diff = diff
        return signals

class Momentum(Strategy):
    def __init__(self, symbol: str, lookback: int = 10, threshold_pct: float = 0.01, trade_qty: int = 1):
        if lookback < 1:
            raise ValueError("lookback must be >= 1")
        if threshold_pct < 0:
            raise ValueError("threshold_pct must be >= 0")
        self.symbol = symbol
        self._window = lookback
        self._th = threshold_pct
        self._prices = deque(maxlen=lookback)
        self._qty = trade_qty

    def generate_signals(self, tick, positions=None):
        if tick.symbol != self.symbol:
            return []
        self._prices.append(tick.price)
        if len(self._prices) < self._window:
            return []
        now = self._prices[-1]
        past = self._prices[0]
        if past <= 0:
            return []
        change = (now - past) / past
        signals: List[Signal] = []
        if change >= self._th:
            signals.append(("BUY", tick.symbol, self._qty))
        elif change <= -self._th:
            current = 0
            if positions and tick.symbol in positions:
                current = int(positions[tick.symbol].get("total_shares", 0))
            qty = min(current, self._qty) if current > 0 else 0
            if qty > 0:
                signals.append(("SELL", tick.symbol, qty))
        
        return signals

# %%
# NOT USING IT
def generateSignals(marketdataPT,positions):
    '''
    genenrate siganls by two strategies
    '''
    #setup
    mac = MovingAverageCrossover()
    mom = Momentum()
    print(marketdataPT)
    MA_signals = mac.generate_signals(tick = marketdataPT, positions = positions)
    mont_signals = mom.generate_signals(tick = marketdataPT, positions = positions)
    return MA_signals,mont_signals

def Makeorder(signal):
    '''
    turn signals into order and validate

    signal format is ("SELL", tick.symbol, self._qty, tick.price)
    '''

    action, symbol, qty, price = signal
    if action not in ("BUY", "SELL"):
        raise OrderError("action must be BUY or SELL")
    if qty <= 0:
        raise OrderError("quantity must be > 0")
    if price <= 0:
        raise OrderError("price must be > 0")
    if action == "SELL":
        held = int(positions.get(symbol, {}).get("total_shares", 0))
        if held < qty:
            raise OrderError(f"insufficient shares to sell (have {held}, need {qty})")

def Makeorders(signals, positions):
    """
    Convert a list of signals into order dicts.
    signal format: ("BUY"/"SELL", symbol, qty, price)
    """
    orders = []
    for sig in signals:
        if len(sig) != 4:
            raise OrderError(f"Signal must be (side, symbol, qty, price), got {sig}")
        side, symbol, qty, price = sig
        side = str(side).upper()

        if side not in ("BUY", "SELL"):
            raise OrderError("action must be BUY or SELL")
        if qty <= 0:
            raise OrderError("quantity must be > 0")
        if price <= 0:
            raise OrderError("price must be > 0")
        if side == "SELL":
            held = int(positions.get(symbol, {}).get("total_shares", 0))
            if held < qty:
                # either raise, or downgrade to partial sell; here we raise to be explicit
                raise OrderError(f"insufficient shares to sell (have {held}, need {qty})")

        orders.append({
            "side": side,
            "symbol": symbol,
            "quantity": int(qty),
            "price": float(price),
        })
    return orders

# %%
listtest = []
if listtest:
    print(1)

# %%
from typing import List, Dict, Iterable, Tuple
class BackTestengine:
    """Drives the backtest: ticks -> signals -> orders -> fills -> portfolio updates."""
    def __init__(self, strategies: Iterable[Strategy]):
        self.strategies = list(strategies)
        self.portfolio = Portfolio()
        self.order_log: List[Order] = []
        self.error_log: List[str] = []

    def _create_orders(self, signals: List[Tuple[str,str,int]], tick: MarketDataPoint):
        orders: List[Order] = []
        for side, symbol, qty in signals:
            o = Order(side=side, symbol=symbol, quantity=int(qty), price=float(tick.price), timestamp=tick.timestamp)
            o.validate()
            orders.append(o)
        return orders

    def _execute(self, order: Order) -> None:
        # simulate flaky execution 3% of the time
        if random.random() < 0.03:
            raise ExecutionError("Simulated venue outage")
        # in a toy engine, all valid orders fill at provided price
        order.status = "FILLED"
        self.portfolio.apply_fill(order)

    def on_tick(self, tick: MarketDataPoint) -> None:
        positions = self.portfolio.snapshot()
        for strat in self.strategies:
            try:    
                signals = strat.generate_signals(tick, positions)

                if not signals:
                    continue
                orders = self._create_orders(signals, tick)
                
                for order in orders:
                    try:
                        self._execute(order)
                    except Exception as ex:
                        order.status = "REJECTED"
                        self.error_log.append(f"{tick.timestamp} {order.symbol} {order.side} x{order.quantity}: EXECUTION ERROR: {ex}")
                    finally:
                        self.order_log.append(order)
            except Exception as ex:
                self.error_log.append(f"{tick.timestamp} Strategy {type(strat).__name__} error: {ex}")

    def run(self, market: Iterable[MarketDataPoint]) -> None:
        for tick in sorted(market, key=lambda t: t.timestamp):
            self.on_tick(tick)

    def report(self) -> Dict:
        return {
            "positions": self.portfolio.snapshot(),
            "orders": [{
                "time": o.timestamp.isoformat(),
                "symbol": o.symbol,
                "side": o.side,
                "qty": o.quantity,
                "price": o.price,
                "status": o.status
            } for o in self.order_log],
            "errors": list(self.error_log),
        }

# %%
reader = MarketDataReader("market_data.csv")
reader.read_data()
data = reader.fetch_data()
data  = sorted(data, key=lambda t: t.timestamp)
allData = MarketDataContainer()
for dp in data:
    allData.buffer_data(dp)

positions = allData.all_positions

# %%
type(subset)
# Out:
# list

# %%
#collect symbols in the dataset
symbols = sorted({t.symbol for t in allData.buffer})

#  build one instance per strategy per symbol
strats = []
for sym in symbols:
    strats.append(MovingAverageCrossover(symbol=sym, short_window=3, long_window=8, trade_qty=2))
    strats.append(Momentum(symbol=sym, lookback=5, threshold_pct=0.01, trade_qty=1))


# run the engine over ALL ticks (strategies will ignore other symbols)
engine = BackTestengine(strats)
engine.run(sorted(allData.buffer, key=lambda t: t.timestamp))

report = engine.report()
# Out:
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>

# %%
report
# Out:
# {'positions': {},
#  'orders': [],
#  'errors': ["2025-09-20 14:30:22.162233 Strategy MovingAverageCrossover error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:22.162233 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:22.174778 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:22.187338 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:22.199891 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:22.339419 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:22.351957 Strategy MovingAverageCrossover error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:22.351957 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:22.364508 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:22.377043 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:22.439759 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:22.464871 Strategy MovingAverageCrossover error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:22.477445 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:22.488228 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:22.500838 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:22.513406 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:22.525333 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:22.537952 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:22.549276 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:22.561911 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:22.573185 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:22.594679 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:22.629993 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:22.688168 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:22.700743 Strategy MovingAverageCrossover error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:22.700743 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:22.713045 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:22.725640 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:22.738243 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:22.750818 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:22.762518 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:22.775111 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:22.787690 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:22.954900 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:22.965867 Strategy MovingAverageCrossover error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:23.002062 Strategy MovingAverageCrossover error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:23.012752 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:23.128824 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:23.140833 Strategy MovingAverageCrossover error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:23.140833 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:23.153458 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:23.165594 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:23.177536 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:23.313077 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:23.336904 Strategy MovingAverageCrossover error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:23.336904 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:23.394871 Strategy MovingAverageCrossover error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:23.394871 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:23.404956 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:23.417523 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:23.430091 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:23.442496 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:23.455051 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:23.467587 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:23.504983 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:23.528482 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:23.539732 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:23.550945 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:23.563673 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:23.574349 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:23.585661 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:23.596601 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:23.643302 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:23.654959 Strategy MovingAverageCrossover error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:23.654959 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:23.667602 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:23.679240 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:23.757707 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:23.770722 Strategy MovingAverageCrossover error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:23.770722 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:23.783541 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:23.796182 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:23.817956 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:23.828346 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:23.840228 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:23.851968 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:23.877342 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:24.026840 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:24.049739 Strategy MovingAverageCrossover error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:24.256794 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:24.267022 Strategy MovingAverageCrossover error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:24.267022 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:24.277700 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:24.290395 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:24.302843 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:24.326377 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:24.470060 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:24.595961 Strategy MovingAverageCrossover error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:24.595961 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:24.608593 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:24.621153 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:24.634022 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:24.707609 Strategy MovingAverageCrossover error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:24.707609 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:24.719819 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:24.732038 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:24.742184 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:24.754832 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:24.814750 Strategy MovingAverageCrossover error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:24.814750 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:24.849231 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:25.021191 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:25.033797 Strategy MovingAverageCrossover error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:25.033797 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:25.046456 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:25.059116 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:25.071543 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:25.084151 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:25.096782 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:25.109390 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:25.122021 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:25.134276 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:25.146685 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:25.159341 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:25.182390 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:25.221365 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:25.233997 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:25.246091 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:25.258777 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:25.270336 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:25.283443 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:25.296141 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:25.306928 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:25.329018 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:25.439985 Strategy MovingAverageCrossover error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:25.439985 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:25.452348 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:25.464251 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:25.476518 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:25.489132 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:25.499780 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:25.510769 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:25.523412 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:25.536051 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:25.547616 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:25.558376 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:25.754016 Strategy MovingAverageCrossover error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:25.754016 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:25.766590 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:25.779168 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:25.791741 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:25.944916 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:25.957532 Strategy MovingAverageCrossover error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:25.957532 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:26.031473 Strategy MovingAverageCrossover error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:26.031473 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:26.043875 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:26.056525 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:26.068526 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:26.078654 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:26.233366 Strategy MovingAverageCrossover error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:26.233366 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:26.243524 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:26.253943 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:26.277516 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:26.299741 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:26.311186 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:26.321289 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:26.333898 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:26.512335 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:26.523196 Strategy MovingAverageCrossover error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:26.523196 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:26.535799 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:26.548377 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:26.560954 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:26.571539 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:26.614118 Strategy MovingAverageCrossover error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:26.626717 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:26.639315 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:26.651919 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:26.664476 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:26.677060 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:26.772814 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:26.785425 Strategy MovingAverageCrossover error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:26.785425 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:26.798013 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:26.835001 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:26.847667 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:26.860292 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:26.918159 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:26.990279 Strategy MovingAverageCrossover error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:26.990279 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:27.002936 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:27.014509 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:27.027186 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:27.089076 Strategy MovingAverageCrossover error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:27.089076 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:27.101721 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:27.112544 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:27.150094 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:27.171639 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:27.182198 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:27.205010 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:27.254845 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:27.277874 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:27.347181 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:27.359743 Strategy MovingAverageCrossover error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:27.359743 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:27.371506 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:27.444571 Strategy MovingAverageCrossover error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:27.444571 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:27.457153 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:27.469723 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:27.541774 Strategy MovingAverageCrossover error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:27.541774 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:27.609887 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:27.622442 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:27.632757 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:27.644902 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:27.670004 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:27.682545 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:27.815924 Strategy MovingAverageCrossover error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:27.815924 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:27.828506 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:27.841100 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:27.853700 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:27.866011 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:27.878464 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:27.890992 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:27.925645 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:27.936958 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:27.949542 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:28.007987 Strategy MovingAverageCrossover error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:28.007987 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:28.020557 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:28.067676 Strategy MovingAverageCrossover error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:28.079354 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:28.091620 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:28.102490 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:28.115132 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:28.126319 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'",
#   "2025-09-20 14:30:28.137090 Strategy Momentum error: Order.__init__() got an unexpected keyword argument 'timestamp'"]}
